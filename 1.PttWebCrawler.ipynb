# %%
# import urllib3.request as req
import requests 
from random import randint
from time import sleep
import bs4
import re
import winsound
import logging

def getData(pageurl):
    # 預先建立要插入"上一頁url"的列表
    prePageUrl = []
    prePageUrl = [pageurl] if prePageUrl == [] else prePageUrl
    head0 = {"authority": "www.ptt.cc",
"method": "GET",
"scheme": "https",
"referer": "https://www.ptt.cc/bbs/index.html",
"sec-ch-ua-mobile": "?0",
"sec-ch-ua-platform": "Windows",
"sec-fetch-dest": "document",
"sec-fetch-mode": "navigate",
"sec-fetch-site": "same-origin",
"sec-fetch-user": "?1",
"upgrade-insecure-requests": "1",
"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36",
}
    #記得改日期
    path = 'out1008.txt'
    with open(path, 'a',encoding="utf-8") as f:
        # index計數器
        index = 0
        while True:
            # try:
            indexUrl = prePageUrl[0]
            # 計數器+1並印出
            index += 1
            print("準備讀取並解析頁面",index," : ",indexUrl,end="") 
            # 建立要求連進indexUrl的request_i
            head1=head0
            try:
                request_i  = requests.get(indexUrl, headers = head1)
            except:
                print("handshake failure")
                delay = 100
                print("準備睡眠 " + str(delay) + " 秒")
                sleep(delay)   
                request_i  = requests.get(indexUrl, headers = head1)

            ##print("第",index,"連index頁 ",head1["referer"])
            ###request_i = req.Request(indexUrl, headers=head1)
            #傳送request_i物件，向網站表示要連上url
            ###with req.urlopen(request_i) as response:
                # 指定在讀取網頁資料時，以utf8解碼，將讀取的資料放到data變數
            
            ###articleData=response.read().decode("utf-8")
            # root為解析index頁的資料
            root = bs4.BeautifulSoup(request_i.text, "html.parser")
            print("---已進入頁面")
            # 從root中，找出第一個class為"btn-group btn-group-paging"的div標籤
            div_btn_group_paging = root.find("div", class_="btn-group btn-group-paging")
            # 從class為"btn-group btn-group-paging"的div標籤中，取出所有a標籤
            div_btn_group_atags = div_btn_group_paging.find_all("a")
            # 從所有a標籤中，找出innerHTML="‹ 上頁"的a標籤，並將該a標籤的href屬性取出，並在前面加上"https://www.ptt.cc/"
            prePageUrl = ["https://www.ptt.cc/"+div_btn_group_atag.get('href') for div_btn_group_atag in div_btn_group_atags if div_btn_group_atag.string == "‹ 上頁"]
            

            # 從root中，找出第一個class為"title"的div標籤
            divs_title = root.find_all("div", class_="title")
            # 從所有class為"title"的div標籤中取出a標籤，並將該a標籤的href屬性取出，並在前面加上"https://www.ptt.cc/"
            # 將每個取出的文章url加入到articlesUrlList
            articlesUrlList = [ "https://www.ptt.cc/"+div.a.get('href') for div in divs_title if div.a!=None ]
            

            # 建立寫出文章的計數器
            count = 0
            for articleUrl in articlesUrlList:
                head1["referer"]=indexUrl
                count+=1
                print("準備解析目錄第",index,"頁 : 第",count,"篇文章",end="")

                
                URL = articleUrl
                # 將請求(設定Header與Cookie)request物件並發出
                ##print("進文章",head1["referer"])
                try:
                    request_article = requests.get(URL, headers = head1)
                except:
                    print("handshake failure")
                    for _ in range(2):
                        delay =100
                        print("準備睡眠 " + str(delay) + " 秒")
                        sleep(delay)   
                        request_article = requests.get(URL, headers = head1)
                
                ###request_article = req.Request(URL, headers=head1)
                #傳送request物件，向網站表示要連上url
                
                ####with req.urlopen(request_article) as response:
                
                #指定在讀取網頁資料時，以utf8解碼，將讀取的資料放到data變數
                ####articleData=response.read().decode("utf-8")
                        
                #  把網頁程式碼(HTML) 丟入 bs4模組分析
                root_aritcle = bs4.BeautifulSoup(request_article.text,"html.parser")
                print("---已進入頁面")
                ## PTT 上方4個欄位
                header = root_aritcle.find_all('span','article-meta-value')
                if (header == [])or(len(header)<4):
                    print(header)
                    _ = print("無作者、看板、標題、日期資訊") if header == [] else print("作者、看板、標題、日期有缺")
                    continue
                # 作者
                author = header[0].text
                # 看版
                board = header[1].text
                # 標題
                title = header[2].text
                # 日期
                date = header[3].text


                ## 查找所有html 元素 抓出內容
                main_container = root_aritcle.find(id='main-container')
                # 把所有文字都抓出來，把整個內容切割透過 "-- " 切割成2個陣列
                all_text = main_container.text.split('--')
                # 第0個包含作者、看板、標題、日期、內容
                pre_text = all_text[0]
                # 第-1個包含推噓、留言者、留言內容、留言時間
                after_text = all_text[-1]

                    
                # 把每段文字 根據 '\n' 切開
                texts_0 = pre_text.split('\n')
                texts_last = after_text.split('\n')

                # 內容
                contents = texts_0[2:]
                content = '\n'.join(contents)

                # 留言
                postmessages = []
                for i in range(len(texts_last)):
                    if texts_last[i] == "":
                        continue
                    if texts_last[i][0] == "推" or texts_last[i][0]=="→" or texts_last[i][0]=="噓":
                        postmessages = texts_last[i:-3]
                        break
                # 解析留言內容，放入postmessagesList
                pattern = r'(^["推","→","噓"])\s*(\S*)\s*:\s*(\S*[\s?\S?]*\S)\s*(\d\d/\d\d)\s*(\d\d:\d\d)$'
                postmessagesList = []
                for message in postmessages:
                    _ = re.findall(pattern, message)
                    postmessagesList += _

                #文章內容相關變數放入字典
                dict={'作者':author,'看板':board,'標題':title,'日期':date,'內容':content,'留言':postmessagesList}
        
                line = str(dict)+"\n"
                f.writelines(line)
                #睡眠
                # delay = randint(1,5)
                # print("準備睡眠 " + str(delay) + " 秒")
                # sleep(delay)

                head1["referer"]=URL
                    # 將請求(設定Header與Cookie)request物件並發出
                ##print("出文章: ",head1["referer"])
                try:
                    request_article = requests.get(indexUrl, headers = head1)
                except:
                    print("handshake failure")
                    for _ in range(2):
                        delay =100
                        print("準備睡眠 " + str(delay) + " 秒")
                        sleep(delay)   
                        request_article = requests.get(indexUrl, headers = head1)

                #傳送request物件，向網站表示要連上url
            head0["referer"]=indexUrl
            print("---回目錄頁面")
                        
        # except:
        #     if KeyboardInterrupt:
        #         break
        #     else:
        #         print("錯誤發生")
        #         winsound(2000,500)
        #         continue

pageurl="https://www.ptt.cc/bbs/Stock/index.html"
getData(pageurl)
# Out:
# 準備讀取並解析頁面 1  :  https://www.ptt.cc/bbs/Stock/index.html---已進入頁面
# 準備解析目錄第 1 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 1 頁 : 第 15 篇文章---已進入頁面
# []
# 無作者、看板、標題、日期資訊
# 準備解析目錄第 1 頁 : 第 16 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 2  :  https://www.ptt.cc//bbs/Stock/index5606.html---已進入頁面
# 準備解析目錄第 2 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 2 頁 : 第 17 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 3  :  https://www.ptt.cc//bbs/Stock/index5605.html---已進入頁面
# 準備解析目錄第 3 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 3 頁 : 第 15 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 4  :  https://www.ptt.cc//bbs/Stock/index5604.html---已進入頁面
# 準備解析目錄第 4 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 4 頁 : 第 17 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 5  :  https://www.ptt.cc//bbs/Stock/index5603.html---已進入頁面
# 準備解析目錄第 5 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 5 頁 : 第 19 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 6  :  https://www.ptt.cc//bbs/Stock/index5602.html---已進入頁面
# 準備解析目錄第 6 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 6 頁 : 第 16 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 7  :  https://www.ptt.cc//bbs/Stock/index5601.html---已進入頁面
# 準備解析目錄第 7 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 7 頁 : 第 19 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 8  :  https://www.ptt.cc//bbs/Stock/index5600.html---已進入頁面
# 準備解析目錄第 8 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 8 頁 : 第 18 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 9  :  https://www.ptt.cc//bbs/Stock/index5599.html---已進入頁面
# 準備解析目錄第 9 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 9 頁 : 第 19 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 10  :  https://www.ptt.cc//bbs/Stock/index5598.html---已進入頁面
# 準備解析目錄第 10 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 10 頁 : 第 18 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 11  :  https://www.ptt.cc//bbs/Stock/index5597.html---已進入頁面
# 準備解析目錄第 11 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 11 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 12  :  https://www.ptt.cc//bbs/Stock/index5596.html---已進入頁面
# 準備解析目錄第 12 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 12 頁 : 第 19 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 13  :  https://www.ptt.cc//bbs/Stock/index5595.html---已進入頁面
# 準備解析目錄第 13 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 13 頁 : 第 19 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 14  :  https://www.ptt.cc//bbs/Stock/index5594.html---已進入頁面
# 準備解析目錄第 14 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 14 頁 : 第 15 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 15  :  https://www.ptt.cc//bbs/Stock/index5593.html---已進入頁面
# 準備解析目錄第 15 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 15 頁 : 第 17 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 16  :  https://www.ptt.cc//bbs/Stock/index5592.html---已進入頁面
# 準備解析目錄第 16 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 16 頁 : 第 18 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 17  :  https://www.ptt.cc//bbs/Stock/index5591.html---已進入頁面
# 準備解析目錄第 17 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 17 頁 : 第 19 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 18  :  https://www.ptt.cc//bbs/Stock/index5590.html---已進入頁面
# 準備解析目錄第 18 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 18 頁 : 第 19 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 19  :  https://www.ptt.cc//bbs/Stock/index5589.html---已進入頁面
# 準備解析目錄第 19 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 19 頁 : 第 17 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 20  :  https://www.ptt.cc//bbs/Stock/index5588.html---已進入頁面
# 準備解析目錄第 20 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 20 頁 : 第 17 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 21  :  https://www.ptt.cc//bbs/Stock/index5587.html---已進入頁面
# 準備解析目錄第 21 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 21 頁 : 第 18 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 22  :  https://www.ptt.cc//bbs/Stock/index5586.html---已進入頁面
# 準備解析目錄第 22 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 22 頁 : 第 19 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 23  :  https://www.ptt.cc//bbs/Stock/index5585.html---已進入頁面
# 準備解析目錄第 23 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 23 頁 : 第 18 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 24  :  https://www.ptt.cc//bbs/Stock/index5584.html---已進入頁面
# 準備解析目錄第 24 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 24 頁 : 第 19 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 25  :  https://www.ptt.cc//bbs/Stock/index5583.html---已進入頁面
# 準備解析目錄第 25 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 25 頁 : 第 17 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 26  :  https://www.ptt.cc//bbs/Stock/index5582.html---已進入頁面
# 準備解析目錄第 26 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 26 頁 : 第 16 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 27  :  https://www.ptt.cc//bbs/Stock/index5581.html---已進入頁面
# 準備解析目錄第 27 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 27 頁 : 第 18 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 28  :  https://www.ptt.cc//bbs/Stock/index5580.html---已進入頁面
# 準備解析目錄第 28 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 28 頁 : 第 16 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 29  :  https://www.ptt.cc//bbs/Stock/index5579.html---已進入頁面
# 準備解析目錄第 29 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 29 頁 : 第 16 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 30  :  https://www.ptt.cc//bbs/Stock/index5578.html---已進入頁面
# 準備解析目錄第 30 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 30 頁 : 第 18 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 31  :  https://www.ptt.cc//bbs/Stock/index5577.html---已進入頁面
# 準備解析目錄第 31 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 31 頁 : 第 16 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 32  :  https://www.ptt.cc//bbs/Stock/index5576.html---已進入頁面
# 準備解析目錄第 32 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 32 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 33  :  https://www.ptt.cc//bbs/Stock/index5575.html---已進入頁面
# 準備解析目錄第 33 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 33 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 34  :  https://www.ptt.cc//bbs/Stock/index5574.html---已進入頁面
# 準備解析目錄第 34 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 34 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 35  :  https://www.ptt.cc//bbs/Stock/index5573.html---已進入頁面
# 準備解析目錄第 35 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 35 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 36  :  https://www.ptt.cc//bbs/Stock/index5572.html---已進入頁面
# 準備解析目錄第 36 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 36 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 37  :  https://www.ptt.cc//bbs/Stock/index5571.html---已進入頁面
# 準備解析目錄第 37 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 37 頁 : 第 19 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 38  :  https://www.ptt.cc//bbs/Stock/index5570.html---已進入頁面
# 準備解析目錄第 38 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 38 頁 : 第 19 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 39  :  https://www.ptt.cc//bbs/Stock/index5569.html---已進入頁面
# 準備解析目錄第 39 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 39 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 40  :  https://www.ptt.cc//bbs/Stock/index5568.html---已進入頁面
# 準備解析目錄第 40 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 40 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 41  :  https://www.ptt.cc//bbs/Stock/index5567.html---已進入頁面
# 準備解析目錄第 41 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 41 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 42  :  https://www.ptt.cc//bbs/Stock/index5566.html---已進入頁面
# 準備解析目錄第 42 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 42 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 43  :  https://www.ptt.cc//bbs/Stock/index5565.html---已進入頁面
# 準備解析目錄第 43 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 43 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 44  :  https://www.ptt.cc//bbs/Stock/index5564.html---已進入頁面
# 準備解析目錄第 44 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 44 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 45  :  https://www.ptt.cc//bbs/Stock/index5563.html---已進入頁面
# 準備解析目錄第 45 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 45 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 46  :  https://www.ptt.cc//bbs/Stock/index5562.html---已進入頁面
# 準備解析目錄第 46 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 46 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 47  :  https://www.ptt.cc//bbs/Stock/index5561.html---已進入頁面
# 準備解析目錄第 47 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 47 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 48  :  https://www.ptt.cc//bbs/Stock/index5560.html---已進入頁面
# 準備解析目錄第 48 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 48 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 49  :  https://www.ptt.cc//bbs/Stock/index5559.html---已進入頁面
# 準備解析目錄第 49 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 49 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 50  :  https://www.ptt.cc//bbs/Stock/index5558.html---已進入頁面
# 準備解析目錄第 50 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 50 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 51  :  https://www.ptt.cc//bbs/Stock/index5557.html---已進入頁面
# 準備解析目錄第 51 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 51 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 52  :  https://www.ptt.cc//bbs/Stock/index5556.html---已進入頁面
# 準備解析目錄第 52 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 6 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 7 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 8 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 9 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 10 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 11 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 12 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 13 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 14 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 15 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 16 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 17 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 18 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 19 篇文章---已進入頁面
# 準備解析目錄第 52 頁 : 第 20 篇文章---已進入頁面
# ---回目錄頁面
# 準備讀取並解析頁面 53  :  https://www.ptt.cc//bbs/Stock/index5555.html---已進入頁面
# 準備解析目錄第 53 頁 : 第 1 篇文章---已進入頁面
# 準備解析目錄第 53 頁 : 第 2 篇文章---已進入頁面
# 準備解析目錄第 53 頁 : 第 3 篇文章---已進入頁面
# 準備解析目錄第 53 頁 : 第 4 篇文章---已進入頁面
# 準備解析目錄第 53 頁 : 第 5 篇文章---已進入頁面
# 準備解析目錄第 53 頁 : 第 6 篇文章handshake failure
# 準備睡眠 100 秒
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 86, in getData(pageurl)
#      85 try:
# ---> 86     request_article = requests.get(URL, headers = head1)
#      87 except:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 191
#     182         # except:
#     183         #     if KeyboardInterrupt:
#     184         #         break
#    (...)
#     187         #         winsound(2000,500)
#     188         #         continue
#     190 pageurl="https://www.ptt.cc/bbs/Stock/index.html"
# --> 191 getData(pageurl)
#
# Cell In [4], line 92, in getData(pageurl)
#      90         delay =100
#      91         print("準備睡眠 " + str(delay) + " 秒")
# ---> 92         sleep(delay)
#      93         request_article = requests.get(URL, headers = head1)
#      95 ###request_article = req.Request(URL, headers=head1)
#      96 #傳送request物件，向網站表示要連上url
#      97
#    (...)
#     102
#     103 #  把網頁程式碼(HTML) 丟入 bs4模組分析
#
# KeyboardInterrupt:
