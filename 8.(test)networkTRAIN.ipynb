# %%
import matplotlib
import math
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('data1009train.csv',encoding='UTF-8-Sig')
x = torch.tensor(df.iloc[:,1:-1].to_numpy()).to(torch.float32)
y = torch.tensor(df.iloc[:,-1].to_numpy()).to(torch.float32)
x.shape
# Out:
# torch.Size([2164, 168])

# %%
class stockDataSetter(Dataset):
    def __init__(self, x, y=None):
        if y is None:
            self.y = y
        else:
            self.y = torch.FloatTensor(y)
        self.x = torch.FloatTensor(x)

    def __getitem__(self, idx):
        if self.y is None:
            return self.x[idx]
        else:
            return self.x[idx], self.y[idx]
    
    def __len__(self):
        return len(self.x)

# %%
Batchsize = x.shape[0]//20
train_set = stockDataSetter(x, y)
train_loader = DataLoader(train_set, Batchsize,shuffle=True, pin_memory=True)

# %%
import torch
import torch.nn.functional as F   

class My_model(torch.nn.Module): 
    def __init__(self, input_dim):
        super(My_model, self).__init__()
        self.layers = torch.nn.Sequential(
            nn.Linear(input_dim, 168),
            nn.ReLU(),
            nn.Linear(168, 1)
            )
        
    def forward(self, x):
        x = self.layers(x)
        x = x.squeeze(1)
        return x

net = My_model(input_dim=x.shape[1])
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
# optimizer = torch.optim.RAdam(net.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-5, weight_decay=0, foreach=True)
optimizer = torch.optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False, foreach=None, maximize=False, capturable=False)
loss_function = torch.nn.MSELoss(reduction='mean')

print(net)  # net 的结构
# Out:
# My_model(
#   (layers): Sequential(
#     (0): Linear(in_features=168, out_features=168, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=168, out_features=1, bias=True)
#   )
# )

# %%
#訓練
# checkpoint = torch.load('model_state_dict1.pt')
# net.load_state_dict(checkpoint['model_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# epoch = checkpoint['epoch']
# loss = checkpoint['loss']
net = net.train()


best_loss = math.inf
patience_bestloss = 0

bestlossMean = math.inf
loss_50_list = []
patience_meanloss = 0
for t in range(1000000):
    
    x, y = next(iter(train_loader))
    
    prediction = net(x).to(device)
    loss = loss_function(prediction,y).to(device)
    optimizer.zero_grad()
    loss.backward(retain_graph=True)
    optimizer.step()
    

    loss_50_list.append(loss.data.numpy())
    # 接着上面来
    if t % 50 == 0:
        lossMean = sum(loss_50_list)/len(loss_50_list)
        print('================================================')
        print(f'第:{t}輪', 'loss: ',loss.data.numpy())
        print(f'前50輪loss平均: {lossMean}')
        print(f'目前最佳loss: {best_loss}')
        print(f'目前最佳平均loss: {bestlossMean}')
        print('patience_meanloss(最大1000): ',patience_meanloss )
        print('patience_bestloss(最大50000): ',patience_bestloss )
        print('================================================')
        loss_50_list = []
        if lossMean <=bestlossMean:
            bestlossMean = lossMean
            patience_meanloss = 0
        else:
            patience_meanloss+=1
        
        if patience_meanloss == 10000:
            print('平均loss已經10000個batch未下降')
            break
        prelossMean = lossMean
        
    if loss<best_loss and prelossMean == bestlossMean:
        patience_bestloss = 0
        best_loss = loss
        torch.save(net, 'Save_File1.pth')
        torch.save({
            'epoch': t,
            'model_state_dict': net.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss
            }, 'model_state_dict1.pt')
        print(f'儲存model, loss={loss}, 前50輪平均loss={prelossMean}')
    else:
        patience_bestloss += 1
    
    if patience_bestloss >= 50000:
        print('loss已經訓練50000個batch未下降')
        break
# Out:
# ================================================
# 第:0輪 loss:  24366.967
# 前50輪loss平均: 24366.966796875
# 目前最佳loss: inf
# 目前最佳平均loss: inf
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  0
# ================================================
# 儲存model, loss=24366.966796875, 前50輪平均loss=24366.966796875
# 儲存model, loss=19793.61328125, 前50輪平均loss=24366.966796875
# 儲存model, loss=13246.294921875, 前50輪平均loss=24366.966796875
# 儲存model, loss=13228.6875, 前50輪平均loss=24366.966796875
# 儲存model, loss=11557.2412109375, 前50輪平均loss=24366.966796875
# 儲存model, loss=10353.1787109375, 前50輪平均loss=24366.966796875
# ================================================
# 第:50輪 loss:  20258.34
# 前50輪loss平均: 83605.50853515624
# 目前最佳loss: 10353.1787109375
# 目前最佳平均loss: 24366.966796875
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  0
# ================================================
# ================================================
# 第:100輪 loss:  11288.613
# 前50輪loss平均: 18728.758671875
# 目前最佳loss: 10353.1787109375
# 目前最佳平均loss: 24366.966796875
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  50
# ================================================
# ================================================
# 第:150輪 loss:  34010.58
# 前50輪loss平均: 19548.1285546875
# 目前最佳loss: 10353.1787109375
# 目前最佳平均loss: 18728.758671875
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  100
# ================================================
# ================================================
# 第:200輪 loss:  21835.398
# 前50輪loss平均: 19046.04892578125
# 目前最佳loss: 10353.1787109375
# 目前最佳平均loss: 18728.758671875
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  150
# ================================================
# ================================================
# 第:250輪 loss:  11892.138
# 前50輪loss平均: 17432.18810546875
# 目前最佳loss: 10353.1787109375
# 目前最佳平均loss: 18728.758671875
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  200
# ================================================
# 儲存model, loss=10035.8828125, 前50輪平均loss=17432.18810546875
# 儲存model, loss=9220.103515625, 前50輪平均loss=17432.18810546875
# ================================================
# 第:300輪 loss:  24368.885
# 前50輪loss平均: 17362.0108984375
# 目前最佳loss: 9220.103515625
# 目前最佳平均loss: 17432.18810546875
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  11
# ================================================
# ================================================
# 第:350輪 loss:  26080.705
# 前50輪loss平均: 18181.77080078125
# 目前最佳loss: 9220.103515625
# 目前最佳平均loss: 17362.0108984375
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  61
# ================================================
# ================================================
# 第:400輪 loss:  12539.664
# 前50輪loss平均: 18459.277890625
# 目前最佳loss: 9220.103515625
# 目前最佳平均loss: 17362.0108984375
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  111
# ================================================
# ================================================
# 第:450輪 loss:  25901.373
# 前50輪loss平均: 19614.7584375
# 目前最佳loss: 9220.103515625
# 目前最佳平均loss: 17362.0108984375
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  161
# ================================================
# ================================================
# 第:500輪 loss:  24247.95
# 前50輪loss平均: 19650.516064453124
# 目前最佳loss: 9220.103515625
# 目前最佳平均loss: 17362.0108984375
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  211
# ================================================
# ================================================
# 第:550輪 loss:  22574.088
# 前50輪loss平均: 19049.7454296875
# 目前最佳loss: 9220.103515625
# 目前最佳平均loss: 17362.0108984375
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  261
# ================================================
# ================================================
# 第:600輪 loss:  22268.21
# 前50輪loss平均: 20660.18138671875
# 目前最佳loss: 9220.103515625
# 目前最佳平均loss: 17362.0108984375
# patience_meanloss(最大1000):  5
# patience_bestloss(最大50000):  311
# ================================================
# ================================================
# 第:650輪 loss:  16389.44
# 前50輪loss平均: 16899.79228515625
# 目前最佳loss: 9220.103515625
# 目前最佳平均loss: 17362.0108984375
# patience_meanloss(最大1000):  6
# patience_bestloss(最大50000):  361
# ================================================
# 儲存model, loss=9217.919921875, 前50輪平均loss=16899.79228515625
# 儲存model, loss=8664.7841796875, 前50輪平均loss=16899.79228515625
# ================================================
# 第:700輪 loss:  15449.235
# 前50輪loss平均: 18309.29677734375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  5
# ================================================
# ================================================
# 第:750輪 loss:  17239.51
# 前50輪loss平均: 18250.2715625
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  55
# ================================================
# ================================================
# 第:800輪 loss:  15699.988
# 前50輪loss平均: 20838.494609375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  105
# ================================================
# ================================================
# 第:850輪 loss:  17021.734
# 前50輪loss平均: 17420.962421875
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  155
# ================================================
# ================================================
# 第:900輪 loss:  20406.861
# 前50輪loss平均: 17587.872451171876
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  205
# ================================================
# ================================================
# 第:950輪 loss:  17890.586
# 前50輪loss平均: 17934.65703125
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  5
# patience_bestloss(最大50000):  255
# ================================================
# ================================================
# 第:1000輪 loss:  17605.18
# 前50輪loss平均: 18905.96185546875
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  6
# patience_bestloss(最大50000):  305
# ================================================
# ================================================
# 第:1050輪 loss:  20712.883
# 前50輪loss平均: 19020.32607421875
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  7
# patience_bestloss(最大50000):  355
# ================================================
# ================================================
# 第:1100輪 loss:  25649.734
# 前50輪loss平均: 17572.82546875
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  8
# patience_bestloss(最大50000):  405
# ================================================
# ================================================
# 第:1150輪 loss:  17136.479
# 前50輪loss平均: 19824.49052734375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  9
# patience_bestloss(最大50000):  455
# ================================================
# ================================================
# 第:1200輪 loss:  14567.571
# 前50輪loss平均: 18294.2810546875
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  10
# patience_bestloss(最大50000):  505
# ================================================
# ================================================
# 第:1250輪 loss:  31700.996
# 前50輪loss平均: 19750.480859375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  11
# patience_bestloss(最大50000):  555
# ================================================
# ================================================
# 第:1300輪 loss:  11832.149
# 前50輪loss平均: 20993.8011328125
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  12
# patience_bestloss(最大50000):  605
# ================================================
# ================================================
# 第:1350輪 loss:  19617.17
# 前50輪loss平均: 17039.94912109375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  13
# patience_bestloss(最大50000):  655
# ================================================
# ================================================
# 第:1400輪 loss:  14910.0205
# 前50輪loss平均: 18952.72279296875
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  14
# patience_bestloss(最大50000):  705
# ================================================
# ================================================
# 第:1450輪 loss:  17787.51
# 前50輪loss平均: 18368.12798828125
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  15
# patience_bestloss(最大50000):  755
# ================================================
# ================================================
# 第:1500輪 loss:  11583.522
# 前50輪loss平均: 18560.42849609375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  16
# patience_bestloss(最大50000):  805
# ================================================
# ================================================
# 第:1550輪 loss:  21301.814
# 前50輪loss平均: 16656.059140625
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16899.79228515625
# patience_meanloss(最大1000):  17
# patience_bestloss(最大50000):  855
# ================================================
# ================================================
# 第:1600輪 loss:  14094.269
# 前50輪loss平均: 19161.43423828125
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16656.059140625
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  905
# ================================================
# ================================================
# 第:1650輪 loss:  25938.541
# 前50輪loss平均: 16279.63806640625
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16656.059140625
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  955
# ================================================
# ================================================
# 第:1700輪 loss:  20631.115
# 前50輪loss平均: 17214.0412109375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  1005
# ================================================
# ================================================
# 第:1750輪 loss:  18321.598
# 前50輪loss平均: 17738.099765625
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  1055
# ================================================
# ================================================
# 第:1800輪 loss:  20870.746
# 前50輪loss平均: 18861.0087109375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  1105
# ================================================
# ================================================
# 第:1850輪 loss:  15221.108
# 前50輪loss平均: 17334.6605859375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  1155
# ================================================
# ================================================
# 第:1900輪 loss:  16672.16
# 前50輪loss平均: 18515.8851953125
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  1205
# ================================================
# ================================================
# 第:1950輪 loss:  14388.214
# 前50輪loss平均: 17131.152109375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  5
# patience_bestloss(最大50000):  1255
# ================================================
# ================================================
# 第:2000輪 loss:  30464.717
# 前50輪loss平均: 18530.3733984375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  6
# patience_bestloss(最大50000):  1305
# ================================================
# ================================================
# 第:2050輪 loss:  9759.667
# 前50輪loss平均: 17405.57609375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  7
# patience_bestloss(最大50000):  1355
# ================================================
# ================================================
# 第:2100輪 loss:  12230.224
# 前50輪loss平均: 17820.24857421875
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  8
# patience_bestloss(最大50000):  1405
# ================================================
# ================================================
# 第:2150輪 loss:  15862.044
# 前50輪loss平均: 16903.2014453125
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  9
# patience_bestloss(最大50000):  1455
# ================================================
# ================================================
# 第:2200輪 loss:  22547.701
# 前50輪loss平均: 19914.98189453125
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  10
# patience_bestloss(最大50000):  1505
# ================================================
# ================================================
# 第:2250輪 loss:  16768.43
# 前50輪loss平均: 16903.51228515625
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  11
# patience_bestloss(最大50000):  1555
# ================================================
# ================================================
# 第:2300輪 loss:  15954.954
# 前50輪loss平均: 17741.11462890625
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  12
# patience_bestloss(最大50000):  1605
# ================================================
# ================================================
# 第:2350輪 loss:  11009.277
# 前50輪loss平均: 16730.88521484375
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  13
# patience_bestloss(最大50000):  1655
# ================================================
# ================================================
# 第:2400輪 loss:  13680.821
# 前50輪loss平均: 16987.493203125
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  14
# patience_bestloss(最大50000):  1705
# ================================================
# ================================================
# 第:2450輪 loss:  14789.262
# 前50輪loss平均: 16155.50501953125
# 目前最佳loss: 8664.7841796875
# 目前最佳平均loss: 16279.63806640625
# patience_meanloss(最大1000):  15
# patience_bestloss(最大50000):  1755
# ================================================
# 儲存model, loss=8266.2353515625, 前50輪平均loss=16155.50501953125
# 儲存model, loss=7155.85205078125, 前50輪平均loss=16155.50501953125
# ================================================
# 第:2500輪 loss:  15197.417
# 前50輪loss平均: 17013.345244140626
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 16155.50501953125
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  8
# ================================================
# ================================================
# 第:2550輪 loss:  13448.863
# 前50輪loss平均: 17082.07908203125
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 16155.50501953125
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  58
# ================================================
# ================================================
# 第:2600輪 loss:  13795.1
# 前50輪loss平均: 15598.8962890625
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 16155.50501953125
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  108
# ================================================
# ================================================
# 第:2650輪 loss:  9641.6875
# 前50輪loss平均: 15310.3286328125
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15598.8962890625
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  158
# ================================================
# ================================================
# 第:2700輪 loss:  15599.448
# 前50輪loss平均: 15388.89939453125
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15310.3286328125
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  208
# ================================================
# ================================================
# 第:2750輪 loss:  11634.952
# 前50輪loss平均: 15639.253125
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15310.3286328125
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  258
# ================================================
# ================================================
# 第:2800輪 loss:  12475.058
# 前50輪loss平均: 15264.68578125
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15310.3286328125
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  308
# ================================================
# ================================================
# 第:2850輪 loss:  13364.825
# 前50輪loss平均: 16086.745654296876
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15264.68578125
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  358
# ================================================
# ================================================
# 第:2900輪 loss:  26243.922
# 前50輪loss平均: 16117.9332421875
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15264.68578125
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  408
# ================================================
# ================================================
# 第:2950輪 loss:  22947.096
# 前50輪loss平均: 16378.638955078124
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15264.68578125
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  458
# ================================================
# ================================================
# 第:3000輪 loss:  9894.827
# 前50輪loss平均: 15266.9460546875
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15264.68578125
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  508
# ================================================
# ================================================
# 第:3050輪 loss:  22881.037
# 前50輪loss平均: 15791.39763671875
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15264.68578125
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  558
# ================================================
# ================================================
# 第:3100輪 loss:  19085.896
# 前50輪loss平均: 16505.09642578125
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15264.68578125
# patience_meanloss(最大1000):  5
# patience_bestloss(最大50000):  608
# ================================================
# ================================================
# 第:3150輪 loss:  8126.347
# 前50輪loss平均: 15914.510654296875
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15264.68578125
# patience_meanloss(最大1000):  6
# patience_bestloss(最大50000):  658
# ================================================
# ================================================
# 第:3200輪 loss:  16246.983
# 前50輪loss平均: 14912.335107421875
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 15264.68578125
# patience_meanloss(最大1000):  7
# patience_bestloss(最大50000):  708
# ================================================
# ================================================
# 第:3250輪 loss:  24009.414
# 前50輪loss平均: 16421.71796875
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 14912.335107421875
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  758
# ================================================
# ================================================
# 第:3300輪 loss:  10631.371
# 前50輪loss平均: 16130.269267578125
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 14912.335107421875
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  808
# ================================================
# ================================================
# 第:3350輪 loss:  16015.531
# 前50輪loss平均: 16946.6276171875
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 14912.335107421875
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  858
# ================================================
# ================================================
# 第:3400輪 loss:  13332.89
# 前50輪loss平均: 15163.51455078125
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 14912.335107421875
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  908
# ================================================
# ================================================
# 第:3450輪 loss:  14589.881
# 前50輪loss平均: 16277.841484375
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 14912.335107421875
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  958
# ================================================
# ================================================
# 第:3500輪 loss:  13126.35
# 前50輪loss平均: 14785.001318359375
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 14912.335107421875
# patience_meanloss(最大1000):  5
# patience_bestloss(最大50000):  1008
# ================================================
# ================================================
# 第:3550輪 loss:  15483.02
# 前50輪loss平均: 14707.64091796875
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 14785.001318359375
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  1058
# ================================================
# ================================================
# 第:3600輪 loss:  17422.092
# 前50輪loss平均: 14319.3692578125
# 目前最佳loss: 7155.85205078125
# 目前最佳平均loss: 14707.64091796875
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  1108
# ================================================
# 儲存model, loss=6620.17724609375, 前50輪平均loss=14319.3692578125
# ================================================
# 第:3650輪 loss:  9217.094
# 前50輪loss平均: 14417.21369140625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 14319.3692578125
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  22
# ================================================
# ================================================
# 第:3700輪 loss:  18709.955
# 前50輪loss平均: 17670.37755859375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 14319.3692578125
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  72
# ================================================
# ================================================
# 第:3750輪 loss:  11573.389
# 前50輪loss平均: 15762.666845703125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 14319.3692578125
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  122
# ================================================
# ================================================
# 第:3800輪 loss:  11138.425
# 前50輪loss平均: 14391.241513671876
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 14319.3692578125
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  172
# ================================================
# ================================================
# 第:3850輪 loss:  22106.725
# 前50輪loss平均: 13849.15794921875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 14319.3692578125
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  222
# ================================================
# ================================================
# 第:3900輪 loss:  18334.102
# 前50輪loss平均: 15247.124443359375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13849.15794921875
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  272
# ================================================
# ================================================
# 第:3950輪 loss:  23518.535
# 前50輪loss平均: 14698.974873046875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13849.15794921875
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  322
# ================================================
# ================================================
# 第:4000輪 loss:  12370.124
# 前50輪loss平均: 15883.313203125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13849.15794921875
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  372
# ================================================
# ================================================
# 第:4050輪 loss:  13974.884
# 前50輪loss平均: 14835.9703125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13849.15794921875
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  422
# ================================================
# ================================================
# 第:4100輪 loss:  16700.824
# 前50輪loss平均: 14309.321904296876
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13849.15794921875
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  472
# ================================================
# ================================================
# 第:4150輪 loss:  10602.532
# 前50輪loss平均: 14898.6708203125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13849.15794921875
# patience_meanloss(最大1000):  5
# patience_bestloss(最大50000):  522
# ================================================
# ================================================
# 第:4200輪 loss:  20232.049
# 前50輪loss平均: 15849.31109375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13849.15794921875
# patience_meanloss(最大1000):  6
# patience_bestloss(最大50000):  572
# ================================================
# ================================================
# 第:4250輪 loss:  15571.569
# 前50輪loss平均: 15368.850078125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13849.15794921875
# patience_meanloss(最大1000):  7
# patience_bestloss(最大50000):  622
# ================================================
# ================================================
# 第:4300輪 loss:  10611.013
# 前50輪loss平均: 14868.234482421874
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13849.15794921875
# patience_meanloss(最大1000):  8
# patience_bestloss(最大50000):  672
# ================================================
# ================================================
# 第:4350輪 loss:  16101.304
# 前50輪loss平均: 13827.91353515625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13849.15794921875
# patience_meanloss(最大1000):  9
# patience_bestloss(最大50000):  722
# ================================================
# ================================================
# 第:4400輪 loss:  10471.757
# 前50輪loss平均: 14803.546474609375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13827.91353515625
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  772
# ================================================
# ================================================
# 第:4450輪 loss:  8789.629
# 前50輪loss平均: 15197.98279296875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13827.91353515625
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  822
# ================================================
# ================================================
# 第:4500輪 loss:  17776.3
# 前50輪loss平均: 14508.034404296875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13827.91353515625
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  872
# ================================================
# ================================================
# 第:4550輪 loss:  15212.265
# 前50輪loss平均: 14772.9678125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13827.91353515625
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  922
# ================================================
# ================================================
# 第:4600輪 loss:  11058.09
# 前50輪loss平均: 14810.22958984375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13827.91353515625
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  972
# ================================================
# ================================================
# 第:4650輪 loss:  15614.576
# 前50輪loss平均: 13596.56716796875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13827.91353515625
# patience_meanloss(最大1000):  5
# patience_bestloss(最大50000):  1022
# ================================================
# ================================================
# 第:4700輪 loss:  16141.15
# 前50輪loss平均: 14368.614248046875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13596.56716796875
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  1072
# ================================================
# ================================================
# 第:4750輪 loss:  13647.059
# 前50輪loss平均: 14893.205966796875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13596.56716796875
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  1122
# ================================================
# ================================================
# 第:4800輪 loss:  12233.025
# 前50輪loss平均: 15304.95927734375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13596.56716796875
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  1172
# ================================================
# ================================================
# 第:4850輪 loss:  12660.687
# 前50輪loss平均: 14732.59947265625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13596.56716796875
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  1222
# ================================================
# ================================================
# 第:4900輪 loss:  19938.062
# 前50輪loss平均: 14397.71443359375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13596.56716796875
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  1272
# ================================================
# ================================================
# 第:4950輪 loss:  9323.191
# 前50輪loss平均: 12615.977001953124
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 13596.56716796875
# patience_meanloss(最大1000):  5
# patience_bestloss(最大50000):  1322
# ================================================
# ================================================
# 第:5000輪 loss:  16619.39
# 前50輪loss平均: 14755.96208984375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  1372
# ================================================
# ================================================
# 第:5050輪 loss:  14306.988
# 前50輪loss平均: 14720.9523046875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  1422
# ================================================
# ================================================
# 第:5100輪 loss:  21021.324
# 前50輪loss平均: 15339.95919921875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  1472
# ================================================
# ================================================
# 第:5150輪 loss:  8221.077
# 前50輪loss平均: 13471.26677734375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  1522
# ================================================
# ================================================
# 第:5200輪 loss:  13074.682
# 前50輪loss平均: 14274.87318359375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  1572
# ================================================
# ================================================
# 第:5250輪 loss:  17323.629
# 前50輪loss平均: 14197.04060546875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  5
# patience_bestloss(最大50000):  1622
# ================================================
# ================================================
# 第:5300輪 loss:  16887.244
# 前50輪loss平均: 13677.629375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  6
# patience_bestloss(最大50000):  1672
# ================================================
# ================================================
# 第:5350輪 loss:  14572.715
# 前50輪loss平均: 14749.45232421875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  7
# patience_bestloss(最大50000):  1722
# ================================================
# ================================================
# 第:5400輪 loss:  24354.29
# 前50輪loss平均: 14082.1969140625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  8
# patience_bestloss(最大50000):  1772
# ================================================
# ================================================
# 第:5450輪 loss:  17454.049
# 前50輪loss平均: 14578.31462890625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  9
# patience_bestloss(最大50000):  1822
# ================================================
# ================================================
# 第:5500輪 loss:  15135.728
# 前50輪loss平均: 14991.98609375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  10
# patience_bestloss(最大50000):  1872
# ================================================
# ================================================
# 第:5550輪 loss:  13622.9795
# 前50輪loss平均: 14585.521640625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  11
# patience_bestloss(最大50000):  1922
# ================================================
# ================================================
# 第:5600輪 loss:  20028.754
# 前50輪loss平均: 13857.87619140625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  12
# patience_bestloss(最大50000):  1972
# ================================================
# ================================================
# 第:5650輪 loss:  7678.5254
# 前50輪loss平均: 14186.016044921875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  13
# patience_bestloss(最大50000):  2022
# ================================================
# ================================================
# 第:5700輪 loss:  16480.697
# 前50輪loss平均: 15071.640859375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  14
# patience_bestloss(最大50000):  2072
# ================================================
# ================================================
# 第:5750輪 loss:  16873.736
# 前50輪loss平均: 14206.775859375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  15
# patience_bestloss(最大50000):  2122
# ================================================
# ================================================
# 第:5800輪 loss:  15905.437
# 前50輪loss平均: 13910.5878125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  16
# patience_bestloss(最大50000):  2172
# ================================================
# ================================================
# 第:5850輪 loss:  21779.514
# 前50輪loss平均: 14198.8091796875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  17
# patience_bestloss(最大50000):  2222
# ================================================
# ================================================
# 第:5900輪 loss:  17314.22
# 前50輪loss平均: 13412.497490234375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  18
# patience_bestloss(最大50000):  2272
# ================================================
# ================================================
# 第:5950輪 loss:  13647.285
# 前50輪loss平均: 13624.427666015625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  19
# patience_bestloss(最大50000):  2322
# ================================================
# ================================================
# 第:6000輪 loss:  10799.517
# 前50輪loss平均: 14934.81623046875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  20
# patience_bestloss(最大50000):  2372
# ================================================
# ================================================
# 第:6050輪 loss:  13289.813
# 前50輪loss平均: 14925.502451171875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  21
# patience_bestloss(最大50000):  2422
# ================================================
# ================================================
# 第:6100輪 loss:  13390.145
# 前50輪loss平均: 15272.31564453125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  22
# patience_bestloss(最大50000):  2472
# ================================================
# ================================================
# 第:6150輪 loss:  12618.952
# 前50輪loss平均: 13383.494287109375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  23
# patience_bestloss(最大50000):  2522
# ================================================
# ================================================
# 第:6200輪 loss:  17228.611
# 前50輪loss平均: 14535.719814453125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  24
# patience_bestloss(最大50000):  2572
# ================================================
# ================================================
# 第:6250輪 loss:  12590.82
# 前50輪loss平均: 14457.435185546876
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  25
# patience_bestloss(最大50000):  2622
# ================================================
# ================================================
# 第:6300輪 loss:  18419.992
# 前50輪loss平均: 14183.33421875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  26
# patience_bestloss(最大50000):  2672
# ================================================
# ================================================
# 第:6350輪 loss:  6888.83
# 前50輪loss平均: 14019.673525390624
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  27
# patience_bestloss(最大50000):  2722
# ================================================
# ================================================
# 第:6400輪 loss:  15769.983
# 前50輪loss平均: 14155.722841796874
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  28
# patience_bestloss(最大50000):  2772
# ================================================
# ================================================
# 第:6450輪 loss:  12834.712
# 前50輪loss平均: 14442.142890625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  29
# patience_bestloss(最大50000):  2822
# ================================================
# ================================================
# 第:6500輪 loss:  13120.458
# 前50輪loss平均: 13839.84365234375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  30
# patience_bestloss(最大50000):  2872
# ================================================
# ================================================
# 第:6550輪 loss:  8395.549
# 前50輪loss平均: 13881.24720703125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  31
# patience_bestloss(最大50000):  2922
# ================================================
# ================================================
# 第:6600輪 loss:  8363.031
# 前50輪loss平均: 13813.36828125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  32
# patience_bestloss(最大50000):  2972
# ================================================
# ================================================
# 第:6650輪 loss:  9785.529
# 前50輪loss平均: 13346.3180859375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  33
# patience_bestloss(最大50000):  3022
# ================================================
# ================================================
# 第:6700輪 loss:  14745.331
# 前50輪loss平均: 13414.875458984376
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  34
# patience_bestloss(最大50000):  3072
# ================================================
# ================================================
# 第:6750輪 loss:  9605.553
# 前50輪loss平均: 13164.15271484375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  35
# patience_bestloss(最大50000):  3122
# ================================================
# ================================================
# 第:6800輪 loss:  11377.98
# 前50輪loss平均: 14500.444296875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  36
# patience_bestloss(最大50000):  3172
# ================================================
# ================================================
# 第:6850輪 loss:  8815.724
# 前50輪loss平均: 13147.5774609375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  37
# patience_bestloss(最大50000):  3222
# ================================================
# ================================================
# 第:6900輪 loss:  11882.52
# 前50輪loss平均: 13264.053994140624
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  38
# patience_bestloss(最大50000):  3272
# ================================================
# ================================================
# 第:6950輪 loss:  14526.907
# 前50輪loss平均: 13849.963583984376
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  39
# patience_bestloss(最大50000):  3322
# ================================================
# ================================================
# 第:7000輪 loss:  19060.566
# 前50輪loss平均: 14305.694228515626
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  40
# patience_bestloss(最大50000):  3372
# ================================================
# ================================================
# 第:7050輪 loss:  11308.043
# 前50輪loss平均: 12526.040888671874
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12615.977001953124
# patience_meanloss(最大1000):  41
# patience_bestloss(最大50000):  3422
# ================================================
# ================================================
# 第:7100輪 loss:  16333.077
# 前50輪loss平均: 12840.121005859375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12526.040888671874
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  3472
# ================================================
# ================================================
# 第:7150輪 loss:  19581.623
# 前50輪loss平均: 13065.279345703126
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12526.040888671874
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  3522
# ================================================
# ================================================
# 第:7200輪 loss:  12540.696
# 前50輪loss平均: 13167.686044921875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12526.040888671874
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  3572
# ================================================
# ================================================
# 第:7250輪 loss:  14872.614
# 前50輪loss平均: 13522.890947265625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12526.040888671874
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  3622
# ================================================
# ================================================
# 第:7300輪 loss:  9850.884
# 前50輪loss平均: 12444.67494140625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12526.040888671874
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  3672
# ================================================
# ================================================
# 第:7350輪 loss:  12962.952
# 前50輪loss平均: 14226.767958984376
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  3722
# ================================================
# ================================================
# 第:7400輪 loss:  8008.325
# 前50輪loss平均: 14310.163330078125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  3772
# ================================================
# ================================================
# 第:7450輪 loss:  12122.05
# 前50輪loss平均: 13177.54564453125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  3822
# ================================================
# ================================================
# 第:7500輪 loss:  9787.66
# 前50輪loss平均: 13966.9452734375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  3872
# ================================================
# ================================================
# 第:7550輪 loss:  19539.574
# 前50輪loss平均: 14035.03068359375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  3922
# ================================================
# ================================================
# 第:7600輪 loss:  13648.64
# 前50輪loss平均: 13044.399892578125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  5
# patience_bestloss(最大50000):  3972
# ================================================
# ================================================
# 第:7650輪 loss:  13427.566
# 前50輪loss平均: 13196.730634765625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  6
# patience_bestloss(最大50000):  4022
# ================================================
# ================================================
# 第:7700輪 loss:  13955.608
# 前50輪loss平均: 14213.452685546876
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  7
# patience_bestloss(最大50000):  4072
# ================================================
# ================================================
# 第:7750輪 loss:  11138.3545
# 前50輪loss平均: 14242.277451171874
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  8
# patience_bestloss(最大50000):  4122
# ================================================
# ================================================
# 第:7800輪 loss:  21506.527
# 前50輪loss平均: 14183.950576171876
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  9
# patience_bestloss(最大50000):  4172
# ================================================
# ================================================
# 第:7850輪 loss:  9197.696
# 前50輪loss平均: 13718.47181640625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  10
# patience_bestloss(最大50000):  4222
# ================================================
# ================================================
# 第:7900輪 loss:  12306.445
# 前50輪loss平均: 13743.99400390625
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  11
# patience_bestloss(最大50000):  4272
# ================================================
# ================================================
# 第:7950輪 loss:  14994.0625
# 前50輪loss平均: 13313.130078125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  12
# patience_bestloss(最大50000):  4322
# ================================================
# ================================================
# 第:8000輪 loss:  10938.97
# 前50輪loss平均: 13130.827607421876
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  13
# patience_bestloss(最大50000):  4372
# ================================================
# ================================================
# 第:8050輪 loss:  11459.106
# 前50輪loss平均: 12597.451591796875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  14
# patience_bestloss(最大50000):  4422
# ================================================
# ================================================
# 第:8100輪 loss:  17043.184
# 前50輪loss平均: 13155.697841796875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  15
# patience_bestloss(最大50000):  4472
# ================================================
# ================================================
# 第:8150輪 loss:  11503.471
# 前50輪loss平均: 12883.536669921876
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  16
# patience_bestloss(最大50000):  4522
# ================================================
# ================================================
# 第:8200輪 loss:  10980.767
# 前50輪loss平均: 13313.5068359375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  17
# patience_bestloss(最大50000):  4572
# ================================================
# ================================================
# 第:8250輪 loss:  8697.088
# 前50輪loss平均: 13567.45365234375
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  18
# patience_bestloss(最大50000):  4622
# ================================================
# ================================================
# 第:8300輪 loss:  14561.89
# 前50輪loss平均: 13591.36453125
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  19
# patience_bestloss(最大50000):  4672
# ================================================
# ================================================
# 第:8350輪 loss:  14072.786
# 前50輪loss平均: 12220.54482421875
# 目前最佳loss: 6620.17724609375
# 目前最佳平均loss: 12444.67494140625
# patience_meanloss(最大1000):  20
# patience_bestloss(最大50000):  4722
# ================================================
# 儲存model, loss=6327.8095703125, 前50輪平均loss=12220.54482421875
# ================================================
# 第:8400輪 loss:  22471.049
# 前50輪loss平均: 13452.2278515625
# 目前最佳loss: 6327.8095703125
# 目前最佳平均loss: 12220.54482421875
# patience_meanloss(最大1000):  0
# patience_bestloss(最大50000):  42
# ================================================
# ================================================
# 第:8450輪 loss:  15095.631
# 前50輪loss平均: 13526.886162109375
# 目前最佳loss: 6327.8095703125
# 目前最佳平均loss: 12220.54482421875
# patience_meanloss(最大1000):  1
# patience_bestloss(最大50000):  92
# ================================================
# ================================================
# 第:8500輪 loss:  14327.957
# 前50輪loss平均: 13089.20583984375
# 目前最佳loss: 6327.8095703125
# 目前最佳平均loss: 12220.54482421875
# patience_meanloss(最大1000):  2
# patience_bestloss(最大50000):  142
# ================================================
# ================================================
# 第:8550輪 loss:  14003.564
# 前50輪loss平均: 13363.404853515625
# 目前最佳loss: 6327.8095703125
# 目前最佳平均loss: 12220.54482421875
# patience_meanloss(最大1000):  3
# patience_bestloss(最大50000):  192
# ================================================
# ================================================
# 第:8600輪 loss:  8871.555
# 前50輪loss平均: 12182.3503125
# 目前最佳loss: 6327.8095703125
# 目前最佳平均loss: 12220.54482421875
# patience_meanloss(最大1000):  4
# patience_bestloss(最大50000):  242
# ================================================
# ...
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  693
# patience_bestloss(最大50000):  47108
# ================================================
# ================================================
# 第:133200輪 loss:  4519.1426
# 前50輪loss平均: 6649.003620605468
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  694
# patience_bestloss(最大50000):  47158
# ================================================
# ================================================
# 第:133250輪 loss:  3969.328
# 前50輪loss平均: 6684.441484375
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  695
# patience_bestloss(最大50000):  47208
# ================================================
# ================================================
# 第:133300輪 loss:  11554.921
# 前50輪loss平均: 6904.961687011719
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  696
# patience_bestloss(最大50000):  47258
# ================================================
# ================================================
# 第:133350輪 loss:  5366.747
# 前50輪loss平均: 6326.632622070312
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  697
# patience_bestloss(最大50000):  47308
# ================================================
# ================================================
# 第:133400輪 loss:  3201.859
# 前50輪loss平均: 6594.949519042969
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  698
# patience_bestloss(最大50000):  47358
# ================================================
# ================================================
# 第:133450輪 loss:  7903.57
# 前50輪loss平均: 6575.146000976562
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  699
# patience_bestloss(最大50000):  47408
# ================================================
# ================================================
# 第:133500輪 loss:  5476.6885
# 前50輪loss平均: 6227.604069824219
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  700
# patience_bestloss(最大50000):  47458
# ================================================
# ================================================
# 第:133550輪 loss:  16095.88
# 前50輪loss平均: 5921.731088867187
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  701
# patience_bestloss(最大50000):  47508
# ================================================
# ================================================
# 第:133600輪 loss:  5665.2593
# 前50輪loss平均: 6226.803852539062
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  702
# patience_bestloss(最大50000):  47558
# ================================================
# ================================================
# 第:133650輪 loss:  5946.705
# 前50輪loss平均: 7011.798530273438
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  703
# patience_bestloss(最大50000):  47608
# ================================================
# ================================================
# 第:133700輪 loss:  9262.595
# 前50輪loss平均: 6893.1299975585935
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  704
# patience_bestloss(最大50000):  47658
# ================================================
# ================================================
# 第:133750輪 loss:  6032.308
# 前50輪loss平均: 6142.569675292969
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  705
# patience_bestloss(最大50000):  47708
# ================================================
# ================================================
# 第:133800輪 loss:  8309.708
# 前50輪loss平均: 5792.006206054688
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  706
# patience_bestloss(最大50000):  47758
# ================================================
# ================================================
# 第:133850輪 loss:  5949.504
# 前50輪loss平均: 6923.431108398438
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  707
# patience_bestloss(最大50000):  47808
# ================================================
# ================================================
# 第:133900輪 loss:  12094.508
# 前50輪loss平均: 6720.574470214844
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  708
# patience_bestloss(最大50000):  47858
# ================================================
# ================================================
# 第:133950輪 loss:  7292.077
# 前50輪loss平均: 7448.184736328125
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  709
# patience_bestloss(最大50000):  47908
# ================================================
# ================================================
# 第:134000輪 loss:  8959.251
# 前50輪loss平均: 6779.34921875
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  710
# patience_bestloss(最大50000):  47958
# ================================================
# ================================================
# 第:134050輪 loss:  9373.192
# 前50輪loss平均: 6295.680627441407
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  711
# patience_bestloss(最大50000):  48008
# ================================================
# ================================================
# 第:134100輪 loss:  7812.0527
# 前50輪loss平均: 6160.380029296875
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  712
# patience_bestloss(最大50000):  48058
# ================================================
# ================================================
# 第:134150輪 loss:  4360.5913
# 前50輪loss平均: 5919.7146826171875
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  713
# patience_bestloss(最大50000):  48108
# ================================================
# ================================================
# 第:134200輪 loss:  4266.021
# 前50輪loss平均: 7084.840251464844
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  714
# patience_bestloss(最大50000):  48158
# ================================================
# ================================================
# 第:134250輪 loss:  2888.726
# 前50輪loss平均: 6693.122990722656
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  715
# patience_bestloss(最大50000):  48208
# ================================================
# ================================================
# 第:134300輪 loss:  7721.015
# 前50輪loss平均: 7246.0144873046875
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  716
# patience_bestloss(最大50000):  48258
# ================================================
# ================================================
# 第:134350輪 loss:  8503.451
# 前50輪loss平均: 6927.400112304687
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  717
# patience_bestloss(最大50000):  48308
# ================================================
# ================================================
# 第:134400輪 loss:  3683.3547
# 前50輪loss平均: 7330.11869140625
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  718
# patience_bestloss(最大50000):  48358
# ================================================
# ================================================
# 第:134450輪 loss:  3888.3694
# 前50輪loss平均: 6886.584501953125
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  719
# patience_bestloss(最大50000):  48408
# ================================================
# ================================================
# 第:134500輪 loss:  6506.79
# 前50輪loss平均: 6323.083403320313
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  720
# patience_bestloss(最大50000):  48458
# ================================================
# ================================================
# 第:134550輪 loss:  2271.5112
# 前50輪loss平均: 6716.085759277344
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  721
# patience_bestloss(最大50000):  48508
# ================================================
# ================================================
# 第:134600輪 loss:  6229.8022
# 前50輪loss平均: 6677.303486328125
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  722
# patience_bestloss(最大50000):  48558
# ================================================
# ================================================
# 第:134650輪 loss:  6316.7974
# 前50輪loss平均: 7229.4983984375
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  723
# patience_bestloss(最大50000):  48608
# ================================================
# ================================================
# 第:134700輪 loss:  4325.021
# 前50輪loss平均: 7027.014926757813
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  724
# patience_bestloss(最大50000):  48658
# ================================================
# ================================================
# 第:134750輪 loss:  4503.1377
# 前50輪loss平均: 6982.963896484375
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  725
# patience_bestloss(最大50000):  48708
# ================================================
# ================================================
# 第:134800輪 loss:  4183.695
# 前50輪loss平均: 6596.782041015625
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  726
# patience_bestloss(最大50000):  48758
# ================================================
# ================================================
# 第:134850輪 loss:  6423.877
# 前50輪loss平均: 6808.655869140625
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  727
# patience_bestloss(最大50000):  48808
# ================================================
# ================================================
# 第:134900輪 loss:  8207.156
# 前50輪loss平均: 6144.206342773437
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  728
# patience_bestloss(最大50000):  48858
# ================================================
# ================================================
# 第:134950輪 loss:  3079.106
# 前50輪loss平均: 6050.131811523437
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  729
# patience_bestloss(最大50000):  48908
# ================================================
# ================================================
# 第:135000輪 loss:  3059.2424
# 前50輪loss平均: 7133.004829101563
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  730
# patience_bestloss(最大50000):  48958
# ================================================
# ================================================
# 第:135050輪 loss:  6899.166
# 前50輪loss平均: 6804.528781738281
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  731
# patience_bestloss(最大50000):  49008
# ================================================
# ================================================
# 第:135100輪 loss:  8171.523
# 前50輪loss平均: 6513.81001953125
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  732
# patience_bestloss(最大50000):  49058
# ================================================
# ================================================
# 第:135150輪 loss:  4580.399
# 前50輪loss平均: 6293.674106445313
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  733
# patience_bestloss(最大50000):  49108
# ================================================
# ================================================
# 第:135200輪 loss:  5289.5435
# 前50輪loss平均: 6624.364638671875
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  734
# patience_bestloss(最大50000):  49158
# ================================================
# ================================================
# 第:135250輪 loss:  2796.2795
# 前50輪loss平均: 6487.545234375
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  735
# patience_bestloss(最大50000):  49208
# ================================================
# ================================================
# 第:135300輪 loss:  5045.9907
# 前50輪loss平均: 5705.611589355469
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  736
# patience_bestloss(最大50000):  49258
# ================================================
# ================================================
# 第:135350輪 loss:  4194.0093
# 前50輪loss平均: 8337.095405273438
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  737
# patience_bestloss(最大50000):  49308
# ================================================
# ================================================
# 第:135400輪 loss:  4565.234
# 前50輪loss平均: 6417.1505517578125
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  738
# patience_bestloss(最大50000):  49358
# ================================================
# ================================================
# 第:135450輪 loss:  12615.302
# 前50輪loss平均: 7487.85541015625
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  739
# patience_bestloss(最大50000):  49408
# ================================================
# ================================================
# 第:135500輪 loss:  3859.964
# 前50輪loss平均: 6159.9601171875
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  740
# patience_bestloss(最大50000):  49458
# ================================================
# ================================================
# 第:135550輪 loss:  5222.706
# 前50輪loss平均: 6400.588125
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  741
# patience_bestloss(最大50000):  49508
# ================================================
# ================================================
# 第:135600輪 loss:  2526.54
# 前50輪loss平均: 7137.044790039063
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  742
# patience_bestloss(最大50000):  49558
# ================================================
# ================================================
# 第:135650輪 loss:  7055.654
# 前50輪loss平均: 6529.9701171875
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  743
# patience_bestloss(最大50000):  49608
# ================================================
# ================================================
# 第:135700輪 loss:  4657.8115
# 前50輪loss平均: 6229.666003417969
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  744
# patience_bestloss(最大50000):  49658
# ================================================
# ================================================
# 第:135750輪 loss:  6652.8022
# 前50輪loss平均: 6653.476025390625
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  745
# patience_bestloss(最大50000):  49708
# ================================================
# ================================================
# 第:135800輪 loss:  9547.861
# 前50輪loss平均: 5930.143884277344
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  746
# patience_bestloss(最大50000):  49758
# ================================================
# ================================================
# 第:135850輪 loss:  9515.863
# 前50輪loss平均: 6936.883544921875
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  747
# patience_bestloss(最大50000):  49808
# ================================================
# ================================================
# 第:135900輪 loss:  8138.962
# 前50輪loss平均: 7080.9989013671875
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  748
# patience_bestloss(最大50000):  49858
# ================================================
# ================================================
# 第:135950輪 loss:  3838.3489
# 前50輪loss平均: 7625.258969726562
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  749
# patience_bestloss(最大50000):  49908
# ================================================
# ================================================
# 第:136000輪 loss:  11888.617
# 前50輪loss平均: 6360.11541015625
# 目前最佳loss: 2193.371826171875
# 目前最佳平均loss: 5663.2894140625
# patience_meanloss(最大1000):  750
# patience_bestloss(最大50000):  49958
# ================================================
# loss已經訓練50000個batch未下降

# %%
#檢查
checkpoint = torch.load('model_state_dict1.pt')
net.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
net = net.eval()

prediction = net(x).to(device)
loss = loss_function(prediction,y).to(device)

pred,actual = pd.DataFrame(prediction.data.numpy()), pd.DataFrame(y.data.numpy())
compare = pd.DataFrame(columns=['actual','predict'])
compare['actual'],compare['predict'] = y.data.numpy(), prediction.data.numpy()
compare = compare.T
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [8], line 3
#       1 #檢查
#       2 checkpoint = torch.load('model_state_dict1.pt')
# ----> 3 net.load_state_dict(checkpoint['model_state_dict'])
#       4 optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#       5 epoch = checkpoint['epoch']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1604, in Module.load_state_dict(self, state_dict, strict)
#    1599         error_msgs.insert(
#    1600             0, 'Missing key(s) in state_dict: {}. '.format(
#    1601                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1603 if len(error_msgs) > 0:
# -> 1604     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1605                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1606 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for My_model:
# 	Unexpected key(s) in state_dict: "layers.4.weight", "layers.4.bias", "layers.6.weight", "layers.6.bias", "layers.8.weight", "layers.8.bias", "layers.10.weight", "layers.10.bias", "layers.12.weight", "layers.12.bias", "layers.14.weight", "layers.14.bias", "layers.16.weight", "layers.16.bias".
# 	size mismatch for layers.2.weight: copying a param with shape torch.Size([148, 168]) from checkpoint, the shape in current model is torch.Size([1, 168]).
# 	size mismatch for layers.2.bias: copying a param with shape torch.Size([148]) from checkpoint, the shape in current model is torch.Size([1]).

# %%
ax = plt.gca()
print('loss: ',loss.data.numpy())
compare.T.plot(kind='line',y ='predict',ax=ax,color='black')
compare.T.plot(kind='line',y ='actual',ax=ax,color='red')
plt.show()
compare
# Display all model layer weights
# for name, para in net.named_parameters():
#     print('{}: {}'.format(name, para.shape))

# %%
r2_score(compare.T['actual'],compare.T['predict'])
# Out:
# 0.9997916465926044
